# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghuvamsiImadabattuni/Raghu-vamsi_INFO5731_Fall2021/blob/main/INFO5731_Assignment_Three_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment. (Use 500 records amount all the data you collected).

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as the 500 reviews (abstracts, or tweets).

# %%
# Question 1 (1)
import pandas as pd
df = pd.read_csv('/content/Iphone_11_reviewws.csv', sep='|', encoding='latin-1')
df.head()
# Out:
#                                   Review_Description
# 0  Purchased this product advertised as fully unl...
# 1  I was feeling a bit skeptical after I placed m...
# 2             Phone was not unlocked could it use it
# 3  The screen came cracked and popped out of the ...
# 4  Be careful mine had a scratch on screen very s...

# %%
# natural language processing: n-gram ranking
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
# add appropriate words that will be ignored in the analysis
ADDITIONAL_STOPWORDS = ['covfefe']

import matplotlib.pyplot as plt

# %%
def basic_clean(text):
  """
  A simple function to clean up the data. All the words that
  are not designated as a stop word is then lemmatized after
  encoding and basic regex parsing are performed.
  """
  wnl = nltk.stem.WordNetLemmatizer()
  stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
  text = (unicodedata.normalize('NFKD', text)
    .encode('ascii', 'ignore')
    .decode('utf-8', 'ignore')
    .lower())
  words = re.sub(r'[^\w\s]', '', text).split()
  return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
import nltk
nltk.download('wordnet')
  
words = basic_clean(''.join(str(df['Review_Description'].tolist())))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words
# Out:
# ['purchased',
#  'product',
#  'advertised',
#  'fully',
#  'unlocked',
#  'inserted',
#  'sim',
#  'card',
#  'work',
#  'contacted',
#  'service',
#  'provider',
#  'checked',
#  'imei',
#  'number',
#  'reported',
#  'phone',
#  'still',
#  'locked',
#  'original',
#  'carrier',
#  'phone',
#  'came',
#  'good',
#  'condition',
#  'couldnt',
#  'use',
#  'service',
#  'provider',
#  'feeling',
#  'bit',
#  'skeptical',
#  'placed',
#  'order',
#  'proven',
#  'wrong',
#  'phone',
#  'look',
#  'brand',
#  'new',
#  'besides',
#  'minimal',
#  'light',
#  'scratch',
#  'almost',
#  'impossible',
#  'notice',
#  'battery',
#  'life',
#  'still',
#  '100',
#  'also',
#  'like',
#  'screen',
#  'protector',
#  'phone',
#  'phone',
#  'unlocked',
#  'could',
#  'use',
#  'screen',
#  'came',
#  'cracked',
#  'popped',
#  'frame',
#  'hopefully',
#  'return',
#  'process',
#  'go',
#  'smoothly',
#  'careful',
#  'mine',
#  'scratch',
#  'screen',
#  'small',
#  'still',
#  'used',
#  'people',
#  'dont',
#  'want',
#  'used',
#  'phone',
#  'scratch',
#  'best',
#  'experience',
#  'ever',
#  'buying',
#  'renewed',
#  'phone',
#  'phone',
#  'came',
#  'itx92s',
#  'original',
#  'box',
#  'original',
#  'charger',
#  'cable',
#  'phone',
#  'look',
#  'excellent',
#  'one',
#  'scratch',
#  'absolutely',
#  'beautiful',
#  'battery',
#  'health',
#  '100',
#  'definitely',
#  'recommend',
#  'seller',
#  'gooverstock',
#  'definitely',
#  'buying',
#  'fought',
#  'longest',
#  'time',
#  'finally',
#  'gave',
#  'upgraded',
#  'iphone',
#  '11',
#  'iphone',
#  '7',
#  'looked',
#  'place',
#  'online',
#  'price',
#  'way',
#  'price',
#  'point',
#  'felt',
#  'comfortable',
#  'buying',
#  'phone',
#  'amazon',
#  'certified',
#  'refurbished',
#  'ix92m',
#  'still',
#  'happy',
#  'box',
#  'didnx92t',
#  'come',
#  'ear',
#  'phone',
#  'phone',
#  'kept',
#  'turning',
#  'set',
#  'apps',
#  'deleted',
#  'theyx92d',
#  'quit',
#  'shutting',
#  'wanna',
#  'tell',
#  'everybody',
#  'scam',
#  'phone',
#  'amazing',
#  'great',
#  'battery',
#  'life',
#  'face',
#  'id',
#  'everything',
#  'unfortunately',
#  'mine',
#  'didnx92t',
#  'come',
#  'iphone',
#  'box',
#  'much',
#  'worried',
#  'come',
#  'w',
#  'charger',
#  'please',
#  'get',
#  'phone',
#  'donx92t',
#  'let',
#  'review',
#  'scare',
#  'month',
#  'review',
#  'phone',
#  'update',
#  'brand',
#  'new',
#  'unlocked',
#  'ix92m',
#  'paired',
#  'cricket',
#  'everything',
#  'transferred',
#  'easily',
#  'working',
#  'well',
#  'far',
#  'look',
#  'new',
#  'iphone',
#  'came',
#  'big',
#  'scuff',
#  'corner',
#  'aluminum',
#  'frame',
#  'small',
#  'really',
#  'noticible',
#  'scratch',
#  'front',
#  'back',
#  'phone',
#  'got',
#  '64',
#  'gb',
#  'product',
#  'red',
#  'unlocked',
#  'iphone',
#  '11',
#  'believe',
#  'verizon',
#  'unlocked',
#  'phone',
#  'phone',
#  'came',
#  'iphone',
#  '11',
#  'apple',
#  'box',
#  'original',
#  'apple',
#  'charger',
#  'original',
#  'apple',
#  'brick',
#  'set',
#  'phone',
#  'put',
#  'tmobile',
#  'sim',
#  'phone',
#  'started',
#  'working',
#  'data',
#  'need',
#  'get',
#  'activated',
#  'anything',
#  'phone',
#  'start',
#  'thats',
#  'sad',
#  'phone',
#  'look',
#  'like',
#  'new',
#  'received',
#  'phone',
#  'day',
#  'early',
#  'came',
#  'exactly',
#  'imagined',
#  'little',
#  'nervous',
#  'buying',
#  'refurbished',
#  'phone',
#  'internet',
#  'truly',
#  'complaint',
#  'phone',
#  'came',
#  'perfect',
#  'like',
#  'new',
#  'condition',
#  'working',
#  'great',
#  'carrier',
#  'general',
#  'came',
#  'charger',
#  'charging',
#  'block',
#  'mentioned',
#  'description',
#  'also',
#  'came',
#  'screen',
#  'protector',
#  'already',
#  'put',
#  'screen',
#  'awesome',
#  'much',
#  'appreciated',
#  'touch',
#  'therex92s',
#  'also',
#  '60',
#  'day',
#  'warranty',
#  'free',
#  'return',
#  'case',
#  'something',
#  'happen',
#  'ix92m',
#  'incredibly',
#  'pleased',
#  'would',
#  'definitely',
#  'recommend',
#  'anyone',
#  'disappointed',
#  'purchase',
#  'price',
#  'brand',
#  'new',
#  'apple',
#  'iphone',
#  'phone',
#  '2',
#  'deep',
#  'scratch',
#  'screen',
#  'come',
#  'earphone',
#  'apple',
#  'charging',
#  'cord',
#  'although',
#  'sticker',
#  'saying',
#  'apple',
#  'charger',
#  'also',
#  'never',
#  'able',
#  'install',
#  'cloud',
#  'using',
#  'iphones',
#  'long',
#  'time',
#  'needed',
#  'new',
#  'one',
#  'saw',
#  'online',
#  'good',
#  'price',
#  'dont',
#  'complaint',
#  'work',
#  'great',
#  'camera',
#  'quality',
#  'amazing',
#  'came',
#  'charger',
#  'come',
#  'headphone',
#  'come',
#  'classic',
#  'x93iphonex94',
#  'packaging',
#  'didnt',
#  'bug',
#  'people',
#  'might',
#  'care',
#  'definitely',
#  'recommend',
#  'want',
#  'headphone',
#  'id',
#  'buy',
#  'separately',
#  'amazon',
#  'renewed',
#  'phone',
#  'expecting',
#  'minor',
#  'cosmetic',
#  'issue',
#  'described',
#  'however',
#  'decent',
#  'size',
#  'mark',
#  'volume',
#  'button',
#  'volume',
#  'button',
#  'function',
#  'properly',
#  'contacted',
#  'amazon',
#  'seller',
#  'gotten',
#  'resolved',
#  'donx92t',
#  'trust',
#  'refurbished',
#  'phone',
#  'tech',
#  'exchange',
#  'ear',
#  'speaker',
#  'phone',
#  'work',
#  'turn',
#  'phone',
#  'speaker',
#  'phone',
#  'make',
#  'phone',
#  'call',
#  'try',
#  'take',
#  'speakerphone',
#  'hear',
#  'garbled',
#  'voice',
#  'lot',
#  'static',
#  'understand',
#  'every',
#  '10th',
#  'word',
#  'today',
#  'trying',
#  'make',
#  'phone',
#  'call',
#  'speakerphone',
#  'every',
#  'time',
#  'pushed',
#  'one',
#  'number',
#  'dial',
#  'number',
#  'pack',
#  'made',
#  'really',
#  'loud',
#  'highpitched',
#  'tone',
#  'hit',
#  'side',
#  'button',
#  'try',
#  'shut',
#  'sound',
#  'screen',
#  'went',
#  'black',
#  'still',
#  'making',
#  'weird',
#  'highpitched',
#  'sound',
#  'ended',
#  'stopping',
#  '3045',
#  'second',
#  'annoying',
#  'finally',
#  'shut',
#  'phone',
#  'completely',
#  'turn',
#  'back',
#  'point',
#  'able',
#  'make',
#  'call',
#  'speakerphone',
#  'ix92ve',
#  'never',
#  'problem',
#  'like',
#  'refurbished',
#  'phone',
#  'chat',
#  'amazon',
#  'told',
#  'handle',
#  'seller',
#  'supposed',
#  'calling',
#  'provide',
#  'prepaid',
#  'label',
#  'return',
#  'discus',
#  'replacement',
#  'phone',
#  'return',
#  'policy',
#  'say',
#  'return',
#  'phone',
#  'two',
#  'week',
#  'give',
#  'refund',
#  'money',
#  'another',
#  'two',
#  'week',
#  'order',
#  'different',
#  'phone',
#  'want',
#  'say',
#  'finally',
#  'received',
#  'call',
#  'refund',
#  'processed',
#  'promptly',
#  'havenx92t',
#  'phone',
#  '2',
#  'week',
#  'power',
#  'button',
#  'isnx92t',
#  'working',
#  'seller',
#  'isnx92t',
#  'responding',
#  'iphone',
#  'shipped',
#  'twoday',
#  'delivery',
#  'box',
#  'inside',
#  'fedex',
#  'bag',
#  'came',
#  'opened',
#  'fedex',
#  'bag',
#  'untouched',
#  'presume',
#  'completely',
#  'closed',
#  'sealing',
#  'bag',
#  'phone',
#  'came',
#  'scratch',
#  'sign',
#  'usage',
#  'screen',
#  'protector',
#  'nice',
#  'touch',
#  'generic',
#  'certified',
#  'usb',
#  'cable',
#  'charger',
#  'earphone',
#  'described',
#  'battery',
#  'life',
#  '100',
#  'far',
#  'look',
#  'work',
#  'good',
#  'im',
#  'little',
#  'concerned',
#  'get',
#  'quite',
#  'hot',
#  'back',
#  'im',
#  'math',
#  'believe',
#  '63999',
#  'still',
#  'high',
#  'price',
#  'refurbished',
#  'want',
#  'replace',
#  'generic',
#  'stuff',
#  'purchasing',
#  'original',
#  'charger',
#  'cable',
#  'earpods',
#  'connector',
#  'total',
#  'price',
#  'go',
#  'beyond',
#  'brand',
#  'new',
#  'phone',
#  'great',
#  'product',
#  'look',
#  'work',
#  'exactly',
#  'like',
#  'new',
#  'fully',
#  'unlocked',
#  'compatible',
#  'carrier',
#  'choice',
#  'false',
#  'statement',
#  'add',
#  'amazon',
#  'received',
#  'phone',
#  'paper',
#  'inside',
#  'box',
#  'saying',
#  'compatible',
#  'sprint',
#  'boost',
#  'mobile',
#  'happen',
#  'use',
#  'one',
#  'carrier',
#  'rather',
#  'erasing',
#  'info',
#  'already',
#  'transferred',
#  'old',
#  'phone',
#  'new',
#  'phone',
#  'mailing',
#  'phone',
#  'back',
#  'chose',
#  'switch',
#  'carrier',
#  'additional',
#  'pain',
#  'buyspry',
#  'end',
#  'never',
#  'purchase',
#  'purchased',
#  'iphone',
#  '11',
#  'said',
#  'unlocked',
#  'always',
#  'owned',
#  'unlocked',
#  'iphones',
#  'never',
#  'trouble',
#  'live',
#  'guatemala',
#  'iphone',
#  '11',
#  'working',
#  'day',
#  'sudden',
#  'stopped',
#  'recognizing',
#  'sim',
#  'card',
#  'see',
#  'video',
#  'issue',
#  'sim',
#  'card',
#  'work',
#  'old',
#  'unlocked',
#  'iphone',
#  '8',
#  'since',
#  'usa',
#  'lost',
#  'almost',
#  '600',
#  'beware',
#  'dont',
#  'buy',
#  'product',
#  'complete',
#  'scam',
#  'excelente',
#  'telefono',
#  'muy',
#  'buena',
#  'la',
#  'camara',
#  'lo',
#  'recomiendo',
#  '100',
#  'son',
#  'loved',
#  'phone',
#  'problem',
#  'setting',
#  'anything',
#  'worked',
#  'perfect',
#  'brand',
#  'new',
#  'apple',
#  'box',
#  'well',
#  'received',
#  'phone',
#  'friday3',
#  'day',
#  'earlier',
#  'expectedand',
#  'absolutely',
#  'lovely',
#  'came',
#  'generic',
#  'box',
#  'apple',
#  'compatible',
#  'charger',
#  'cable',
#  'scratch',
#  'imperfection',
#  'see',
#  'time',
#  'battery',
#  'capacity',
#  '100',
#  'look',
#  'work',
#  'like',
#  'brand',
#  'new',
#  'device',
#  'every',
#  'thing',
#  'right',
#  'battery',
#  'came',
#  '100',
#  'capacity',
#  'arrived',
#  '4',
#  'day',
#  'early',
#  'fedex',
#  'got',
#  'color',
#  'device',
#  'storage',
#  'ordered',
#  'there',
#  'scratch',
#  'bare',
#  'screen',
#  'prove',
#  'used',
#  'peeled',
#  'screen',
#  'protector',
#  'came',
#  'could',
#  'put',
#  'tempered',
#  'glass',
#  'one',
#  'theyre',
#  'invisible',
#  'screen',
#  'protector',
#  'phone',
#  'lighting',
#  'fast',
#  'im',
#  'happy',
#  'doubt',
#  'buying',
#  'phone',
#  'werent',
#  'enough',
#  'review',
#  'used',
#  'entirely',
#  'like',
#  'new',
#  'although',
#  'dont',
#  'get',
#  'unboxing',
#  'experience',
#  'buying',
#  'brand',
#  'new',
#  'earbuds',
#  'arent',
#  'included',
#  'im',
#  'happy',
#  'got',
#  'discount',
#  'didnt',
#  'buy',
#  'new',
#  'one',
#  'one',
#  'sit',
#  'around',
#  'get',
#  'scrapped',
#  'part',
#  'something',
#  'honestly',
#  'dropped',
#  '690',
#  'buck',
#  'thing',
#  'gonna',
#  'go',
#  'ballistic',
#  'didnt',
#  'show',
#  'came',
#  'early',
#  'im',
#  'relieved',
#  'happy',
#  'absolutely',
#  'beautiful',
#  'also',
#  'battery',
#  'life',
#  'iphone',
#  'great',
#  'came',
#  '2016',
#  'se',
#  'big',
#  'change',
#  'shopped',
#  'around',
#  'lot',
#  'renewed',
#  'refurbished',
#  'iphone',
#  '11',
#  'cheapest',
#  'really',
#  'close',
#  'selling',
#  'point',
#  'come',
#  '90',
#  'day',
#  'warranty',
#  'refund',
#  'policy',
#  'sold',
#  'amazon',
#  'prime',
#  'received',
#  'phone',
#  '4',
#  'day',
#  'ago',
#  'upgraded',
#  'transferred',
#  'everything',
#  'iphone',
#  '7',
#  '11',
#  'flawlessly',
#  'plus',
#  'phone',
#  'cosmetic',
#  'issue',
#  'look',
#  'brand',
#  'new',
#  'bought',
#  'refurbished',
#  'iphone',
#  '7',
#  '11',
#  'worked',
#  'perfectly',
#  'phone',
#  'come',
#  'original',
#  'iphone',
#  'box',
#  'nice',
#  'bonus',
#  'difference',
#  'company',
#  'send',
#  'unlocked',
#  'iphones',
#  'normal',
#  'cardboard',
#  'box',
#  'work',
#  'perfectly',
#  'work',
#  'totally',
#  'fine',
#  'far',
#  'ix92m',
#  'satisfied',
#  'functionality',
#  'didnx92t',
#  'come',
#  'earphone',
#  'far',
#  'buying',
#  'product',
#  'specific',
#  'seller',
#  'experience',
#  'great',
#  'nothing',
#  'complain',
#  'scratch',
#  'glass',
#  'display',
#  'mention',
#  'werenx92t',
#  'back',
#  'glass',
#  'camera',
#  'lens',
#  'either',
#  'far',
#  'phone',
#  'ix92m',
#  'android',
#  'person',
#  'first',
#  'smartphone',
#  'happened',
#  'iphone',
#  'gone',
#  'couple',
#  'generation',
#  'ix92m',
#  'pleased',
#  'say',
#  'device',
#  'feel',
#  'great',
#  'itx92s',
#  'still',
#  'iphone',
#  'mustnx92t',
#  'give',
#  'full',
#  '5',
#  'star',
#  'review',
#  'android',
#  'gang',
#  'scam',
#  'repeat',
#  'scam',
#  'love',
#  'iphones',
#  'always',
#  'want',
#  'nice',
#  'good',
#  'working',
#  'phone',
#  'know',
#  'wonx92t',
#  'take',
#  'dump',
#  'single',
#  ...]

# %%
(pd.Series(nltk.ngrams(words, 2)).value_counts())
# Out:
# (brand, new)           74
# (battery, life)        68
# (screen, protector)    58
# (iphone, 11)           56
# (phone, came)          49
#                        ..
# (came, scratched)       1
# (card, service)         1
# (day, period)           1
# (arrived, tried)        1
# (refused, accept)       1
# Length: 12418, dtype: int64

# %%
#Count the frequency of all the N-grams (N=3).
(pd.Series(nltk.ngrams(words, 3)).value_counts())
# Out:
# (came, screen, protector)    18
# (like, brand, new)           17
# (look, brand, new)           12
# (work, like, new)             9
# (phone, work, great)          9
#                              ..
# (beautiful, look, like)       1
# (usa, pero, la)               1
# (could, live, went)           1
# (phone, ordered, phone)       1
# (response, itx92s, week)      1
# Length: 15384, dtype: int64

# %%
bigrams_series = (pd.Series(nltk.ngrams(words, 2)).value_counts())
trigrams_series = (pd.Series(nltk.ngrams(words, 3)).value_counts())

# %%
# Calculating probabilities
from textblob import TextBlob
import nltk
nltk.download('punkt')
with open('/content/Iphone_11_reviewws.csv', 'r', encoding='latin-1') as file:
  data_file = file.read()
bi = TextBlob(data_file)
bigrams = bi.ngrams(2)
gram={ }
probability={ }
for bigram in bigrams:
  bigram=tuple(bigram)
  gram[bigram]=gram.get(bigram,0)+1
for a, b in gram.items():
  probability[a]=b/bi.words.count(a[0])
op1 = pd.DataFrame.from_dict(probability, orient = 'index', columns=['bigrams probability'])
op1['bigrams frequency']=[b for b in gram.values()]
op1
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                  bigrams probability  bigrams frequency
# (Review_Description, Purchased)             1.000000                  1
# (Purchased, this)                           0.166667                  6
# (this, product)                             0.029925                 12
# (product, advertised)                       0.015625                  1
# (advertised, as)                            0.181818                  2
# ...                                              ...                ...
# (thats, how)                               0.066667                  1
# (how, well)                                 0.038462                  1
# (charge, holds)                             0.041667                  1
# (holds, Im)                                0.250000                  1
# (really, glad)                              0.020000                  1
#
# [17093 rows x 2 columns]

# %%
#Extracting all noun phrases and their probabilitiese
import spacy
from sklearn.feature_extraction.text import CountVectorizer
nlp = spacy.load("en")
file = open('/content/Iphone_11_reviewws.csv', 'r', encoding='latin-1' )
data_file2 = nlp(file.read())
all_noun_phrases = []
for noun in data_file2.noun_chunks:
  all_noun_phrases.append(noun.text)
print(all_the_noun_phrases)
op2 = pd.DataFrame(all_noun_phrases, columns = ['all_noun_phrases'])
vector_2 = CountVectorizer(ngram_range=(3,3), analyzer='word')
transform_2 = vector_2.fit_transform(output2['all_the_noun_phrases'].values.astype('U')) 
calculating_frequency_2 = sum(transform_2).toarray()[0]
op3 = pd.DataFrame(calculating_frequency_2, index=vector2.get_feature_names(), columns=['all_the_noun_phrases_Frequency'])
op3['all_the_noun_phrases_Probabilities'] = op3 / op3.max()
#output4 = output3.astype(object).transpose() 
op3
# Out:
# []
#                        all_the_noun_phrases_Frequency  all_the_noun_phrases_Probabilities
# 100 battery capacity                                1                            0.033333
# 100 battery health                                  1                            0.033333
# 100 battery life                                    3                            0.100000
# 100 de batería                                      1                            0.033333
# 100 maximum battery                                 1                            0.033333
# ...                                               ...                                 ...
# your debit card                                     1                            0.033333
# your loved one                                      1                            0.033333
# your own phone                                      1                            0.033333
# your personal account                               1                            0.033333
# your unlocked device                                1                            0.033333
#
# [1296 rows x 2 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
import pandas as pd
df = pd.read_csv('/content/Iphone_11_reviewws.csv', sep='|', encoding='latin-1')
df.head()
# Out:
#                                   Review_Description
# 0  Purchased this product advertised as fully unl...
# 1  I was feeling a bit skeptical after I placed m...
# 2             Phone was not unlocked could it use it
# 3  The screen came cracked and popped out of the ...
# 4  Be careful mine had a scratch on screen very s...

# %%
# To build the documents-terms weights (tf*idf) matrix bold text.
tf2 = df.dropna()
tf1 = (tf2['Review_Description'].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index())
tf1.columns = ['Review_Description','tf']
import numpy as np
#calculating tf*idf
for i,j in enumerate(tf1['Review_Description']):
 tf1.loc[i,'idf'] = np.long(df.shape[0]/(len(df[df['Review_Description'].str.contains(j, regex=False)])))
tf1['tf*idf'] = tf1['tf'] * tf1['idf']
tf1 #shows tf.idf values
# Out:
#      Review_Description      tf    idf  tf*idf
# 0                    my   319.0    2.0   638.0
# 1                   and   852.0    1.0   852.0
# 2                    it   673.0    1.0   673.0
# 3               service    23.0   19.0   437.0
# 4                   the  1201.0    1.0  1201.0
# ...                 ...     ...    ...     ...
# 4665             estado     1.0  250.0   250.0
# 4666           .batería     1.0  500.0   500.0
# 4667             holds.     1.0  500.0   500.0
# 4668            switch.     1.0  500.0   500.0
# 4669             quick.     1.0  500.0   500.0
#
# [4670 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
import numpy.linalg as LA

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each of the 500 review (if you collected the data from citeseer, you can think of other text classfication tasks instead of sentiment analysis) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/RaghuvamsiImadabattuni/Raghu-vamsi_INFO5731_Fall2021/blob/main/Iphone_11_reviewws.csv
